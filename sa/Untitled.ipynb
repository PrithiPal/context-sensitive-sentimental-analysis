# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
SCORES1=[-4.600995628434305,-5.374240522980476,-5.456817852315475,-6.892230116643766,-7.4373367283516885,-8.166072345791717,-9.346332732227449,-10.604229471171429,-10.215699692093867]
K1=list(range(1,10))
SCORES2=[-15.45175329724302,-15.836166043369339,-16.233440583110713,-16.379805385752082,-16.372007434198082,-16.563055909591803,-16.717869542291535,-16.97562612442641,-17.17484545171037,-17.235359250656142]
plt.plot(K1,SCORES1)
plt.xlabel('num of topics')
plt.ylabel('umass score')
plt.title('Topic coherence score')

K2=list(range(21,31))
plt.plot(K2,SCORES2)
plt.xlabel('num of topics')
plt.ylabel('umass score')
plt.title('Topic coherence score')
plt.savefig('umass.png')
